# %% [markdown]
# # Exercício 11

# %% [markdown]
# #### 1) Baixe um dos arquivos csv no seguinte link: https://www.kaggle.com/shenba/time-series-datasets?select=sales-of-shampoo-over-a-three-ye.csv

# %% [markdown]
# #### 2) Carregue o arquivo baixado e verifique o seu conteúdo

# %% [markdown]
# #### 3) Caso seja, necessário, faça o pré-processamento dos dados

# %% [markdown]
# #### 4) Aplique validação cruzada de 5 folds para dados temporais na base de dados preprocessada

# %% [markdown]
# #### 5) Para cada cada fold da validação cruzada, faça:
# - Utilize o conjunto de treinamento para a geração de um modelo ARIMA;
# - Faça a predição de valores, onde a quantidade de valores preditos deve ser equivalente ao tamanho conjunto de teste;
# - Calcule pelo menos uma medida de avaliação para cada fold

# %% [markdown]
# #### 6) Imprima o valor médio e o desvio-padrão de cada medida de avaliação utilizada
