# %% [markdown]
# # Exercício 10

# %% [markdown]
# #### 1) Carregue a base de dados https://github.com/jefferson-oliva/databases/blob/main/breast_cancer.csv
#
# - A solução deve usar as bibliotecas pandas, numpy (opcional) e scikit-learn
# - Caso a tarefa seja implementada no Jupyter Notebook, anexar o arquivo ipynb e a base de dados utilizadano Moodle
# - Caso a tarefa seja imaplementada no Google Colab, compartilhar o link no Moodle (não esquecer de liberar a leitura do arquivo ipynb e da base de dados)

# %% [markdown]
# #### 2) Remova o atributo alvo da base de dados e armazene o seu conteúdo em uma variável (e.g. y)

# %% [markdown]
# #### 3) Contrua dois pipelines que contenham, pelo menos:
# - pré-processamento
# - redução de dimensionalidade
# - Um método ensemble de sua escolha, exceto o que você utilizou no exercício 9

# %% [markdown]
# #### 4) Faça a seleção de melhores hiperparâmetros, utilizando GridSearch, para encontrar a "melhor" configuração para cada um dos dois pipelines. Para isso, além da definição de listas de configurações de hiperparâmetros, considere os seguintes parâmetros:
#
# - Scoring: revocação
# - Validação-cruzada (cv): 10 folds

# %% [markdown]
# #### 5) Após a aplicação do GridSearch, para cada uma das duas configurações, faça:
#
# - Imprima os melhores valores de hiperparâmetros
# - Imprima o maior valor de revocação
# - Obtenha o melhor modelo de cada pipeline

# %% [markdown]
# #### 6) Para cada um dos dois melhores modelos gerados, faça:
# - Calcule e imprima a perda
# - Imprima a variâcia e o viés do erro

# %% [markdown]
# #### 7) Faça a predição no conjunto de teste utilizando os melhores modelos e, em seguida imprima para cada um dos modelos:
#
# - Acurácia
# - Sensibilidade
# - Revocação
# - F1-score

# %% [markdown]
# #### 8) Calcule o intervalo de confiança, considerando o nível de segurança de 95%, o erro (1 - acurácia) de cada modelo.

# %% [markdown]
# #### 9) Utilize os melhores hiperparâmetros para treinar avaliar modelos (considerando todo o pipeline, um para cada ensemble) utilizando a validação cruzada de 10 folds. Para isso considere toda a base de dados em (1).
# - Durante a validação cruzada, obtenha a acurácia de cada fold e armazene-a em um arranjo

# %% [markdown]
# #### 10) Calcule a acurácia média e desvio padrão referentes à validação cruzada para cada modelo.

# %% [markdown]
# #### 11) Aplique um teste estatístico de hipótese, considerando um nível de significância de 5%, para comparar os dois modelos utilizando os vetores de acurácia obtidos em (9)
